# %%
from dotenv import load_dotenv
import os
load_dotenv()
storage_account = os.getenv("AZURE_STORAGE_ACCOUNT")
adls_client_id = os.getenv("ADLS_CLIENT_ID")
adls_client_secret = os.getenv("ADLS_CLIENT_SECRET")
adls_tenant_id = os.getenv("ADLS_TENANT_ID")
value = os.getenv('AZURE_DATA_LAKE_CONNECTION_STRING')
container_name = os.getenv('AZURE_CONTAINER_NAME')

# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: python-dotenv in c:\users\asyak\env\lib\site-packages (from -r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: azure-storage-blob in c:\users\asyak\env\lib\site-packages (from -r requirements.txt (line 2)) (12.24.0)
# Collecting azure-storage-file-datalake (from -r requirements.txt (line 3))
#   Downloading azure_storage_file_datalake-12.18.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: azure-identity in c:\users\asyak\env\lib\site-packages (from -r requirements.txt (line 4)) (1.19.0)
# Requirement already satisfied: pyspark in c:\users\asyak\env\lib\site-packages (from -r requirements.txt (line 5)) (3.5.4)
# Requirement already satisfied: sqlalchemy in c:\users\asyak\env\lib\site-packages (from -r requirements.txt (line 7)) (2.0.36)
# Requirement already satisfied: pyodbc in c:\users\asyak\env\lib\site-packages (from -r requirements.txt (line 8)) (5.2.0)
# Requirement already satisfied: msal in c:\users\asyak\env\lib\site-packages (from -r requirements.txt (line 9)) (1.31.1)
# Requirement already satisfied: bs4 in c:\users\asyak\env\lib\site-packages (from -r requirements.txt (line 10)) (0.0.2)
# Requirement already satisfied: azure-core>=1.30.0 in c:\users\asyak\env\lib\site-packages (from azure-storage-blob->-r requirements.txt (line 2)) (1.32.0)
# Requirement already satisfied: cryptography>=2.1.4 in c:\users\asyak\env\lib\site-packages (from azure-storage-blob->-r requirements.txt (line 2)) (44.0.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\asyak\env\lib\site-packages (from azure-storage-blob->-r requirements.txt (line 2)) (4.12.2)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\asyak\env\lib\site-packages (from azure-storage-blob->-r requirements.txt (line 2)) (0.7.2)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\asyak\env\lib\site-packages (from azure-identity->-r requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: py4j==0.10.9.7 in c:\users\asyak\env\lib\site-packages (from pyspark->-r requirements.txt (line 5)) (0.10.9.7)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\asyak\env\lib\site-packages (from pyspark[sql]->-r requirements.txt (line 6)) (2.2.3)
# Requirement already satisfied: pyarrow>=4.0.0 in c:\users\asyak\env\lib\site-packages (from pyspark[sql]->-r requirements.txt (line 6)) (18.1.0)
# Requirement already satisfied: numpy<2,>=1.15 in c:\users\asyak\env\lib\site-packages (from pyspark[sql]->-r requirements.txt (line 6)) (1.26.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\asyak\env\lib\site-packages (from sqlalchemy->-r requirements.txt (line 7)) (3.1.1)
# Requirement already satisfied: requests<3,>=2.0.0 in c:\users\asyak\env\lib\site-packages (from msal->-r requirements.txt (line 9)) (2.32.3)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\asyak\env\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal->-r requirements.txt (line 9)) (2.10.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\asyak\env\lib\site-packages (from bs4->-r requirements.txt (line 10)) (4.12.3)
# Requirement already satisfied: six>=1.11.0 in c:\users\asyak\env\lib\site-packages (from azure-core>=1.30.0->azure-storage-blob->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\asyak\env\lib\site-packages (from cryptography>=2.1.4->azure-storage-blob->-r requirements.txt (line 2)) (1.17.1)
# Requirement already satisfied: portalocker<3,>=1.4 in c:\users\asyak\env\lib\site-packages (from msal-extensions>=1.2.0->azure-identity->-r requirements.txt (line 4)) (2.10.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asyak\env\lib\site-packages (from pandas>=1.0.5->pyspark[sql]->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asyak\env\lib\site-packages (from pandas>=1.0.5->pyspark[sql]->-r requirements.txt (line 6)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asyak\env\lib\site-packages (from pandas>=1.0.5->pyspark[sql]->-r requirements.txt (line 6)) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\asyak\env\lib\site-packages (from requests<3,>=2.0.0->msal->-r requirements.txt (line 9)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asyak\env\lib\site-packages (from requests<3,>=2.0.0->msal->-r requirements.txt (line 9)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asyak\env\lib\site-packages (from requests<3,>=2.0.0->msal->-r requirements.txt (line 9)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asyak\env\lib\site-packages (from requests<3,>=2.0.0->msal->-r requirements.txt (line 9)) (2024.12.14)
# Requirement already satisfied: soupsieve>1.2 in c:\users\asyak\env\lib\site-packages (from beautifulsoup4->bs4->-r requirements.txt (line 10)) (2.6)
# Requirement already satisfied: pycparser in c:\users\asyak\env\lib\site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob->-r requirements.txt (line 2)) (2.22)
# Requirement already satisfied: pywin32>=226 in c:\users\asyak\env\lib\site-packages (from portalocker<3,>=1.4->msal-extensions>=1.2.0->azure-identity->-r requirements.txt (line 4)) (308)
# Downloading azure_storage_file_datalake-12.18.0-py3-none-any.whl (258 kB)
#    ---------------------------------------- 0.0/258.4 kB ? eta -:--:--
#    ---------------------------------------  256.0/258.4 kB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 258.4/258.4 kB 5.3 MB/s eta 0:00:00
# Installing collected packages: azure-storage-file-datalake
# Successfully installed azure-storage-file-datalake-12.18.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from azure.identity import ClientSecretCredential
from azure.storage.blob import BlobServiceClient

# Test credentials
credential = ClientSecretCredential(
    tenant_id= adls_tenant_id,
    client_id= adls_client_id,
    client_secret= adls_client_secret
)

# Test connection
service_client = BlobServiceClient(
    account_url="https://myvisekendatalake.blob.core.windows.net",
    credential=credential
)

# List containers to verify connectivity
print([container.name for container in service_client.list_containers()])
# Out:
# ['iceberg-metadata', 'myviseken-data-lake']

# %%
from azure.storage.blob import BlobServiceClient
import pandas as pd

blob_service_client = BlobServiceClient.from_connection_string(value)

# Access the container and blob
container_name = os.getenv('AZURE_CONTAINER_NAME')
blob_name = "raw/carlist/data_20250102170445.csv"
blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)

# Download the blob content
stream = blob_client.download_blob().readall()

# Load into pandas DataFrame
import io
df = pd.read_csv(io.BytesIO(stream))
print(df.head())
# Out:
#    listing_id                                              title  \
# 0    15774123  2012 Perodua Myvi 1.5 SE Hatchback (MONTHLY RM...
# 1    15964938  2014 Perodua Myvi 1.3 SE Hatchback (MUKA RM289...
# 2    15531831                    2018 Perodua Myvi 1.5 Hatchback
# 3    15642030                  2019 Perodua Myvi 1.5 H Hatchback
# 4    15678245                  2018 Perodua Myvi 1.3 X Hatchback
#
#     installment  year variant  mileage transmission        location  \
# 0  RM 214/month  2012      SE    77500    Automatic  Seri Kembangan
# 1  RM 249/month  2014      SE    57500    Automatic  Seri Kembangan
# 2  RM 555/month  2018      AV    80118    Automatic     Setiawangsa
# 3  RM 576/month  2019       H    57500    Automatic   Petaling Jaya
# 4  RM 511/month  2018       X    85519    Automatic   Petaling Jaya
#
#           state                                      listing_image   price  \
# 0      Selangor  https://img1.icarcdn.com/32147751/main-m_used-...     328
# 1      Selangor  https://img1.icarcdn.com/83946951/main-m_used-...     289
# 2  Kuala Lumpur  https://img1.icarcdn.com/13813551/main-m_used-...  42,800
# 3      Selangor  https://img1.icarcdn.com/03024651/main-m_used-...  44,400
# 4      Selangor  https://img1.icarcdn.com/54287651/main-m_used-...  39,400
#
#                                                  url  \
# 0  https://www.carlist.my/used-cars/2012-perodua-...
# 1  https://www.carlist.my/used-cars/2014-perodua-...
# 2  https://www.carlist.my/used-cars/2018-perodua-...
# 3  https://www.carlist.my/used-cars/2019-perodua-...
# 4  https://www.carlist.my/used-cars/2018-perodua-...
#
#                                                image
# 0  ['https://img1.icarcdn.com/32147751/thumb-l_us...
# 1  ['https://img1.icarcdn.com/83946951/thumb-l_us...
# 2  ['https://img1.icarcdn.com/13813551/thumb-l_us...
# 3  ['https://img1.icarcdn.com/03024651/thumb-l_us...
# 4  ['https://img1.icarcdn.com/54287651/thumb-l_us...

# %%
#REMOVE STATE WITH NULL VALUE AS WE WILL PROCESS IT STATE BY STATE
# distinct_state = df['state'].unique()
# print(distinct_state)
# df[df['state'].isnull()]
df = df[df['state'].isnull() == False]
# df.count()

# %%
from sqlalchemy.engine import create_engine
from datetime import datetime
from sqlalchemy import DateTime, String, Integer, MetaData, Table, Column, text, ForeignKey
from sqlalchemy.types import TEXT


def get_db_connection():
    load_dotenv()
    #LOAD CREDENTIAL FROM .ENV FILE
    server_name = os.getenv("SQL_SERVER")
    database_name = os.getenv("DB_NAME")
    username = os.getenv("DB_USERNAME")
    password = os.getenv("DB_PASSWORD")

    # Connection string using SQL login
    connection_string = (
        f"mssql+pyodbc://{username}:{password}"
        f"@{server_name}.database.windows.net:1433/{database_name}"
        "?driver=ODBC+Driver+18+for+SQL+Server&encrypt=yes&TrustServerCertificate=no&timeout=30"
    )

    # Create the SQLAlchemy engine and connect
    engine = create_engine(connection_string)
    return engine

# %%
def create_table():
    engine = get_db_connection()
    
    metadata_obj = MetaData()
    
    test_staging = Table(
        "test_staging",
        metadata_obj,
        Column("listing_id", String(255)),
        Column("title", String(255)),
        Column("installment", String(60)),
        Column("year", String(255)),
        Column("variant", String(50)),
        Column("mileage", String(255)),
        Column("transmission", String(50)),
        Column("color", String(50)),
        Column("location", String(255)),
        Column("state", String(255), nullable=False),
        Column("listing_image", String(255), nullable=False),
        Column("price", String(255), nullable=False),
        Column("url", String(255), nullable=False),
        Column("image", TEXT, nullable=True),
        Column("car_model", String(50), nullable=False),
        Column("processing_date", DateTime, nullable=False)
        )
    
    metadata_obj.create_all(engine)
   

# create_table()
# Clean up

def drop_table():
    engine = get_db_connection()
    metadata_obj = MetaData()
    
    test_staging = Table(
        "test_staging",
        metadata_obj,
        Column("listing_id", String(255)),
        Column("title", String(255)),
        Column("installment", String(60)),
        Column("year", String(255)),
        Column("variant", String(50)),
        Column("mileage", String(255)),
        Column("transmission", String(50)),
        Column("location", String(255)),
        Column("state", String(255), nullable=False),
        Column("listing_image", String(255), nullable=False),
        Column("price", String(255), nullable=False),
        Column("url", String(255), nullable=False),
        Column("image", TEXT, nullable=True),
        Column("car_model", String(50), nullable=False),
        Column("processing_date", DateTime, nullable=False)
        )
    
    # drop table
    test_staging.drop(engine)

# create_table()
# drop_table()

# %%
import json
def insert_data(df):
    engine = get_db_connection()

    # Add new columns to DataFrame
    df['processing_date'] = datetime.now()
    df['color'] = None
    df['car_model'] = 'myvi'

    with engine.connect() as connection:
        # Enable identity insert
        df['image'] = df['image'].apply(lambda x: json.dumps(x) if x is not None else None)
        df.to_sql('test_staging', engine, if_exists='append', index=False)
        
        # Disable identity insert
        
        connection.commit()

# insert_data(df)

# %%
from sqlalchemy.engine import create_engine
from msal import ConfidentialClientApplication

authority = f"https://login.microsoftonline.com/{adls_tenant_id}"

# Token endpoint
app = ConfidentialClientApplication(adls_client_id, authority=authority, client_credential=adls_client_secret)
token_response = app.acquire_token_for_client(scopes=["https://database.windows.net/.default"])
access_token = token_response["access_token"]

connection_string = (
    f"mssql+pyodbc://{aad_username}:{aad_password}"
    f"@{server_name}.database.windows.net:1433/{database_name}"
    f"?driver=ODBC+Driver+18+for+SQL+Server&authentication=ActiveDirectoryPassword"
)

engine = create_engine(connection_string, connect_args={"token": access_token})
connection = engine.connect()

from sqlalchemy import MetaData
metadata = MetaData()
metadata.reflect(bind=engine)

from sqlalchemy import select
table = metadata.tables['test_table']
query = select([table])
result = connection.execute(query)
for row in result:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3303, in Engine.raw_connection(self)
#    3282 """Return a "raw" DBAPI connection from the connection pool.
#    3283
#    3284 The returned object is a proxied version of the DBAPI
#    (...)
#    3301
#    3302 """
# -> 3303 return self.pool.connect()
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
#     444 The connection is instrumented such that when its
#    (...)
#     447
#     448 """
# --> 449 return _ConnectionFairy._checkout(self)
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/pool/base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1262 if not fairy:
# -> 1263     fairy = _ConnectionRecord.checkout(pool)
#    1265     if threadconns is not None:
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/pool/base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:180, in QueuePool._do_get(self)
#     179 with util.safe_reraise():
# --> 180     self._dec_overflow()
#     181 raise
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:177, in QueuePool._do_get(self)
#     176 try:
# --> 177     return self._create_connection()
#     178 except:
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/pool/base.py:390, in Pool._create_connection(self)
#     388 """Called by subclasses to create a new ConnectionRecord."""
# --> 390 return _ConnectionRecord(self)
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/pool/base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/pool/base.py:901, in _ConnectionRecord.__connect(self)
#     900     with util.safe_reraise():
# --> 901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/pool/base.py:896, in _ConnectionRecord.__connect(self)
#     895 self.starttime = time.time()
# --> 896 self.dbapi_connection = connection = pool._invoke_creator(self)
#     897 pool.logger.debug("Created new connection %r", connection)
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/engine/create.py:643, in create_engine.<locals>.connect(connection_record)
#     641             return connection
# --> 643 return dialect.connect(*cargs, **cparams)
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/engine/default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# OperationalError: ('HYT00', '[HYT00] [Microsoft][ODBC Driver 18 for SQL Server]Login timeout expired (0) (SQLDriverConnect)')
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[25], line 18
#      11 connection_string = (
#      12     f"mssql+pyodbc://{aad_username}:{aad_password}"
#      13     f"@{server_name}.database.windows.net:1433/{database_name}"
#      14     f"?driver=ODBC+Driver+18+for+SQL+Server&authentication=ActiveDirectoryPassword"
#      15 )
#      17 engine = create_engine(connection_string, connect_args={"token": access_token})
# ---> 18 connection = engine.connect()
#      20 from sqlalchemy import MetaData
#      21 metadata = MetaData()
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3279, in Engine.connect(self)
#    3256 def connect(self) -> Connection:
#    3257     """Return a new :class:`_engine.Connection` object.
#    3258
#    3259     The :class:`_engine.Connection` acts as a Python context manager, so
#    (...)
#    3276
#    3277     """
# -> 3279     return self._connection_cls(self)
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/engine/base.py:147, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
# --> 147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#     150         raise
#     151 else:
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2443, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine, is_disconnect, invalidate_pool_on_disconnect, is_pre_ping)
#    2441 elif should_wrap:
#    2442     assert sqlalchemy_exception is not None
# -> 2443     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2444 else:
#    2445     assert exc_info[1] is not None
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     143 if connection is None:
#     144     try:
# --> 145         self._dbapi_connection = engine.raw_connection()
#     146     except dialect.loaded_dbapi.Error as err:
#     147         Connection._handle_dbapi_exception_noconnection(
#     148             err, dialect, engine
#     149         )
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3303, in Engine.raw_connection(self)
#    3281 def raw_connection(self) -> PoolProxiedConnection:
#    3282     """Return a "raw" DBAPI connection from the connection pool.
#    3283
#    3284     The returned object is a proxied version of the DBAPI
#    (...)
#    3301
#    3302     """
# -> 3303     return self.pool.connect()
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     441 def connect(self) -> PoolProxiedConnection:
#     442     """Return a DBAPI connection from the pool.
#     443
#     444     The connection is instrumented such that when its
#    (...)
#     447
#     448     """
# --> 449     return _ConnectionFairy._checkout(self)
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/pool/base.py:1263, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#    1255 @classmethod
#    1256 def _checkout(
#    1257     cls,
#    (...)
#    1260     fairy: Optional[_ConnectionFairy] = None,
#    1261 ) -> _ConnectionFairy:
#    1262     if not fairy:
# -> 1263         fairy = _ConnectionRecord.checkout(pool)
#    1265         if threadconns is not None:
#    1266             threadconns.current = weakref.ref(fairy)
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/pool/base.py:712, in _ConnectionRecord.checkout(cls, pool)
#     710     rec = cast(_ConnectionRecord, pool._do_get())
#     711 else:
# --> 712     rec = pool._do_get()
#     714 try:
#     715     dbapi_connection = rec.get_connection()
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:180, in QueuePool._do_get(self)
#     178     except:
#     179         with util.safe_reraise():
# --> 180             self._dec_overflow()
#     181         raise
#     182 else:
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/pool/impl.py:177, in QueuePool._do_get(self)
#     175 if self._inc_overflow():
#     176     try:
# --> 177         return self._create_connection()
#     178     except:
#     179         with util.safe_reraise():
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/pool/base.py:390, in Pool._create_connection(self)
#     387 def _create_connection(self) -> ConnectionPoolEntry:
#     388     """Called by subclasses to create a new ConnectionRecord."""
# --> 390     return _ConnectionRecord(self)
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/pool/base.py:674, in _ConnectionRecord.__init__(self, pool, connect)
#     672 self.__pool = pool
#     673 if connect:
# --> 674     self.__connect()
#     675 self.finalize_callback = deque()
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/pool/base.py:901, in _ConnectionRecord.__connect(self)
#     899 except BaseException as e:
#     900     with util.safe_reraise():
# --> 901         pool.logger.debug("Error on connect(): %s", e)
#     902 else:
#     903     # in SQLAlchemy 1.4 the first_connect event is not used by
#     904     # the engine, so this will usually not be set
#     905     if pool.dispatch.first_connect:
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     144     assert exc_value is not None
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#     148     self._exc_info = None  # remove potential circular references
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/pool/base.py:896, in _ConnectionRecord.__connect(self)
#     894 try:
#     895     self.starttime = time.time()
# --> 896     self.dbapi_connection = connection = pool._invoke_creator(self)
#     897     pool.logger.debug("Created new connection %r", connection)
#     898     self.fresh = True
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/engine/create.py:643, in create_engine.<locals>.connect(connection_record)
#     640         if connection is not None:
#     641             return connection
# --> 643 return dialect.connect(*cargs, **cparams)
#
# File /usr/local/lib/python3.9/site-packages/sqlalchemy/engine/default.py:616, in DefaultDialect.connect(self, *cargs, **cparams)
#     614 def connect(self, *cargs, **cparams):
#     615     # inherits the docstring from interfaces.Dialect.connect
# --> 616     return self.loaded_dbapi.connect(*cargs, **cparams)
#
# OperationalError: (pyodbc.OperationalError) ('HYT00', '[HYT00] [Microsoft][ODBC Driver 18 for SQL Server]Login timeout expired (0) (SQLDriverConnect)')
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
